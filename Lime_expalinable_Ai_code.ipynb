# %%
# Step 1: Install LIME
# !pip install lime

# Step 2: Import necessary libraries
import lime
import lime.lime_tabular

# Step 3: Create a LIME explainer
explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=['CO', 'NO2', 'Ozone', 'SO2'], class_names=['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous'], mode='classification')

# Step 4: Choose an instance for explanation
i = 0  # Index of the instance to explain (change as needed)
exp = explainer.explain_instance(X_test.values[i], dt_model.predict_proba)
print(exp)
# Step 5: Display the explanation
exp.show_in_notebook(show_table=True)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=a5887218f85eef32e418064ea070d19f275b5e66fe33acf25cfd7282eea69fc5
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e73e3b1ed82> in <cell line: 9>()
#       7
#       8 # Step 3: Create a LIME explainer
# ----> 9 explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=['CO', 'NO2', 'Ozone', 'SO2'], class_names=['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous'], mode='classification')
#      10
#      11 # Step 4: Choose an instance for explanation
#
# ...

# %%
import lime
import lime.lime_tabular
import pandas as pd
import json

# Load your model (example: decision tree, gradient boost, etc.)
# Assuming 'model' is already trained and saved

# Load the data for which you want explanations
# X_test is the test data or the new data you want to predict

# Initialize LIME explainer
explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=X_train.columns, class_names=['Good', 'Moderate', 'Unhealthy'], mode='classification')

# Explain a single prediction (for example, the first instance of X_test)
exp = explainer.explain_instance(X_test.iloc[0],dt_model.predict_proba)

# Convert LIME explanation to JSON
explanation_json = exp.as_list()
instance = X_test.iloc[0].values.reshape(1, -1)
explanation_output = {
    "explanation": explanation_json,
    "prediction_probabilities": dt_model.predict_proba(instance)
}



# Output the explanation as JSON
# Serialize to JSON
#explanation_json_output = json.dumps(explanation_output)

# Output or save the JSON
print(explanation_output)
# Out:
# {'explanation': [('CO <= 1.26', -0.36089785330395063), ('37.37 < Ozone <= 59.42', -0.01005008104178814), ('NO2 <= 40.74', 0.004862436463638299), ('8.89 < SO2 <= 15.60', -0.0002675171449585823)], 'prediction_probabilities': array([[1., 0., 0., 0., 0., 0.]])}
# /usr/local/lib/python3.10/dist-packages/lime/discretize.py:110: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ret[feature] = int(self.lambdas[feature](ret[feature]))
# /usr/local/lib/python3.10/dist-packages/lime/discretize.py:110: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   ret[feature] = int(self.lambdas[feature](ret[feature]))
# ...
